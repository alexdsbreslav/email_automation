# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('/Users/alex/OneDrive - Duke University/2_classes/year4_fall/grades_clean.xlsx')
df = df.set_index('email')

# %%
rng = np.random.RandomState(20191003)
grid = rng.uniform(-1, 1, (len(df), 2))
a = df * grid

# %%
b = a / grid
b = round(b)

# %%
df == b
# Out:
#                  grade_overall  grade_indiv
# email
# aci6@duke.edu             True         True
# amc188@duke.edu           True         True
# sdv6@duke.edu             True        False
# kp193@duke.edu            True         True
# mc555@duke.edu            True        False
# mcl52@duke.edu            True         True
# jy202@duke.edu            True        False
# gyd2@duke.edu             True         True
# zfw2@duke.edu             True        False
# cab139@duke.edu           True         True
# cam128@duke.edu           True         True
# ysb2@duke.edu             True         True
# bar33@duke.edu            True         True
# zas13@duke.edu            True         True
# af152@duke.edu            True         True
# ak445@duke.edu           False         True
# nl137@duke.edu           False         True
# jcs109@duke.edu           True         True
# dms99@duke.edu           False         True
# jbb70@duke.edu            True         True
# ...

# %%
b
# Out:
#                  grade_overall  grade_indiv
# email
# aci6@duke.edu             0.67         0.48
# amc188@duke.edu           0.74         0.58
# sdv6@duke.edu             0.73         0.58
# kp193@duke.edu            0.75         0.60
# mc555@duke.edu            0.76         0.62
# mcl52@duke.edu            0.75         0.62
# jy202@duke.edu            0.78         0.64
# gyd2@duke.edu             0.76         0.65
# zfw2@duke.edu             0.76         0.65
# cab139@duke.edu           0.80         0.70
# cam128@duke.edu           0.80         0.70
# ysb2@duke.edu             0.82         0.72
# bar33@duke.edu            0.83         0.72
# zas13@duke.edu            0.81         0.72
# af152@duke.edu            0.81         0.74
# ak445@duke.edu            0.82         0.74
# nl137@duke.edu            0.83         0.74
# jcs109@duke.edu           0.84         0.74
# dms99@duke.edu            0.83         0.74
# jbb70@duke.edu            0.85         0.76
# ...
